# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import iirnotch, lfilter, filtfilt, sawtooth, square

def odstrani_kvadratni_signal(s: np.ndarray, f: float, fvz: int) -> np.ndarray:
    nyquist = 0.5 * fvz
    harmonics = np.arange(1, fvz // (2 * f), 2) * f
    filtered_signal = s.copy()

    for h_freq in harmonics:
        bandwidth = h_freq * 0.1
        Q = h_freq / bandwidth
        b, a = iirnotch(h_freq, Q, fvz)
        filtered_signal = filtfilt(b, a, filtered_signal)

    return filtered_signal

if __name__ == '__main__':
    fvz = 1000
    t = np.arange(0, 2, 1 / fvz)
    sig = np.sin(2 * np.pi * t)
    #duty=(sig + 1)/2
    s_kvadratni = square(2 * np.pi * 30 * t)
    s_zagasti = sawtooth(2 * np.pi * 15 * t)
    s_vhodni = s_kvadratni + s_zagasti
    s_filtrirani = odstrani_kvadratni_signal(s_vhodni, 30, fvz)

    plt.figure()
    plt.subplot(4, 1, 1)
    plt.plot(t, s_kvadratni)
    plt.title('Kvadratni signal')
    plt.xlabel('Čas [s]')
    plt.ylabel('Amplituda')

    plt.subplot(4, 1, 2)
    plt.plot(t, s_zagasti)
    plt.title('Kvadratni signal')
    plt.xlabel('Čas [s]')
    plt.ylabel('Amplituda')

    plt.subplot(4, 1, 3)
    plt.plot(t, s_vhodni)
    plt.title('Vhodni signal')
    plt.xlabel('Čas [s]')
    plt.ylabel('Amplituda')

    plt.subplot(4, 1, 4)
    plt.plot(t, s_zagasti, label='Žagasti signal')
    plt.plot(t, s_filtrirani, label='Filtrirani signal')
    plt.legend()
    plt.title('Žagasti in filtrirani signal')
    plt.xlabel('Čas [s]')
    plt.ylabel('Amplituda')

    plt.tight_layout()
    plt.show()

# %%
import numpy as np
from pydub import AudioSegment
from scipy.fftpack import fft
from scipy.io.wavfile import read, write
from scipy.signal import iirnotch, filtfilt, butter, sosfiltfilt

def load_mp3(file_path):
    audio = AudioSegment.from_mp3(file_path)
    audio = audio.set_channels(1)
    samples = np.array(audio.get_array_of_samples())
    return audio.frame_rate, samples

def find_frequencies(signal, rate, threshold=0.05):
    N = len(signal)
    T = 1.0 / rate

    yf = fft(signal)
    xf = np.linspace(0.0, 1.0 / (2.0 * T), N // 2)

    peaks = []
    max_val = 2.0 / N * np.abs(yf[:N // 2]).max()
    for i in range(1, N // 2 - 1):
        if (
            2.0 / N * np.abs(yf[i]) > threshold * max_val
            and yf[i - 1] < yf[i]
            and yf[i] > yf[i + 1]
        ):
            peaks.append(xf[i])

    return peaks

def butter_bandstop_filter(f_low, f_high, fs, order=5):
    nyquist = 0.5 * fs
    low = f_low / nyquist
    high = f_high / nyquist
    sos = butter(order, [low, high], btype='bandstop', analog=False, output='sos')
    return sos

def odstrani_signal(s: np.ndarray, ringing_freqs: np.ndarray, fvz: int) -> np.ndarray:
    filtered_signal = s.copy()

    for idx, freq in enumerate(ringing_freqs):
# Obdelava frekvence 19 od 257: 1680.0625440387032 Hz
# Obdelava frekvence 20 od 257: 1680.7032390693216 Hz
# Obdelava frekvence 21 od 257: 1681.5041078575944 Hz
# Obdelava frekvence 22 od 257: 1681.984629130558 Hz
# Obdelava frekvence 23 od 257: 1682.6253241611762 Hz
# Obdelava frekvence 24 od 257: 1683.2660191917946 Hz
# Obdelava frekvence 25 od 257: 1683.7465404647583 Hz
# Obdelava frekvence 26 od 257: 1684.547409253031 Hz
# Obdelava frekvence 27 od 257: 1685.0279305259946 Hz
# Obdelava frekvence 28 od 257: 1685.668625556613 Hz
# Obdelava frekvence 29 od 257: 1686.1491468295767 Hz
# Obdelava frekvence 30 od 257: 1686.7898418601949 Hz
# Obdelava frekvence 31 od 257: 1687.430536890813 Hz
# Obdelava frekvence 32 od 257: 1688.231405679086 Hz
# Obdelava frekvence 33 od 257: 1688.7119269520497 Hz
# Obdelava frekvence 34 od 257: 1689.3526219826679 Hz
# Obdelava frekvence 35 od 257: 1689.672969497977 Hz
# Obdelava frekvence 36 od 257: 1690.47383828625 Hz
# Obdelava frekvence 37 od 257: 1691.4348808321772 Hz
# Obdelava frekvence 38 od 257: 1695.1188772582323 Hz
# Obdelava frekvence 39 od 257: 1695.7595722888504 Hz
# Obdelava frekvence 40 od 257: 1696.8807885924323 Hz
# Obdelava frekvence 41 od 257: 1698.0020048960143 Hz
# Obdelava frekvence 42 od 257: 1699.6037424725598 Hz
# Obdelava frekvence 43 od 257: 1700.2444375031782 Hz
# Obdelava frekvence 44 od 257: 3478.173147468819 Hz
# Obdelava frekvence 45 od 257: 4386.678700885496 Hz
# Obdelava frekvence 46 od 257: 4387.15922215846 Hz
# Obdelava frekvence 47 od 257: 4388.120264704387 Hz
# Obdelava frekvence 48 od 257: 4389.722002280932 Hz
# Obdelava frekvence 49 od 257: 4390.362697311551 Hz
# Obdelava frekvence 50 od 257: 4391.003392342169 Hz
# Obdelava frekvence 51 od 257: 4391.964434888097 Hz
# Obdelava frekvence 52 od 257: 4392.7653036763695 Hz
# Obdelava frekvence 53 od 257: 4393.886519979951 Hz
# Obdelava frekvence 54 od 257: 4394.206867495261 Hz
# Obdelava frekvence 55 od 257: 4394.687388768224 Hz
# Obdelava frekvence 56 od 257: 4395.328083798842 Hz
# Obdelava frekvence 57 od 257: 4395.9687788294605 Hz
# Obdelava frekvence 58 od 257: 4396.449300102424 Hz
# Obdelava frekvence 59 od 257: 4397.089995133043 Hz
# Obdelava frekvence 60 od 257: 4398.05103767897 Hz
# Obdelava frekvence 61 od 257: 4399.172253982551 Hz
# Obdelava frekvence 62 od 257: 4399.8129490131705 Hz
# Obdelava frekvence 63 od 257: 6169.893144853738 Hz
# Obdelava frekvence 64 od 257: 6181.746002920175 Hz
# Obdelava frekvence 65 od 257: 6186.230868134503 Hz
# Obdelava frekvence 66 od 257: 6189.274169529939 Hz
# Obdelava frekvence 67 od 257: 6195.360772320812 Hz
# Obdelava frekvence 68 od 257: 6197.603204927977 Hz
# Obdelava frekvence 69 od 257: 6198.564247473904 Hz
# Obdelava frekvence 70 od 257: 6199.044768746868 Hz
# Obdelava frekvence 71 od 257: 6201.287201354032 Hz
# Obdelava frekvence 72 od 257: 6203.849981476505 Hz
# Obdelava frekvence 73 od 257: 6205.131371537741 Hz
# Obdelava frekvence 74 od 257: 6205.772066568359 Hz
# Obdelava frekvence 75 od 257: 6210.577279297996 Hz
# Obdelava frekvence 76 od 257: 6212.81971190516 Hz
# Obdelava frekvence 77 od 257: 6214.9019707546695 Hz
# Obdelava frekvence 78 od 257: 6218.585967180725 Hz
# Obdelava frekvence 79 od 257: 6223.391179910361 Hz
# Obdelava frekvence 80 od 257: 6224.03187494098 Hz
# Obdelava frekvence 81 od 257: 6224.512396213943 Hz
# Obdelava frekvence 82 od 257: 6225.313265002216 Hz
# Obdelava frekvence 83 od 257: 6226.594655063453 Hz
# Obdelava frekvence 84 od 257: 6230.5989990048165 Hz
# Obdelava frekvence 85 od 257: 6231.239694035435 Hz
# Obdelava frekvence 86 od 257: 6232.360910339016 Hz
# Obdelava frekvence 87 od 257: 6233.0016053696345 Hz
# Obdelava frekvence 88 od 257: 6233.642300400254 Hz
# Obdelava frekvence 89 od 257: 6238.127165614581 Hz
# Obdelava frekvence 90 od 257: 6242.932378344218 Hz
# Obdelava frekvence 91 od 257: 6243.412899617181 Hz
# Obdelava frekvence 92 od 257: 6244.053594647799 Hz
# Obdelava frekvence 93 od 257: 6244.694289678418 Hz
# Obdelava frekvence 94 od 257: 6245.174810951382 Hz
# Obdelava frekvence 95 od 257: 6246.135853497309 Hz
# Obdelava frekvence 96 od 257: 6246.776548527927 Hz
# Obdelava frekvence 97 od 257: 6248.538459862128 Hz
# Obdelava frekvence 98 od 257: 6249.339328650401 Hz
# Obdelava frekvence 99 od 257: 6250.140197438673 Hz
# Obdelava frekvence 100 od 257: 6250.620718711637 Hz
# Obdelava frekvence 101 od 257: 6251.261413742255 Hz
# Obdelava frekvence 102 od 257: 6251.902108772873 Hz
# Obdelava frekvence 103 od 257: 6252.382630045837 Hz
# Obdelava frekvence 104 od 257: 6253.3436725917645 Hz
# Obdelava frekvence 105 od 257: 6253.824193864728 Hz
# Obdelava frekvence 106 od 257: 6254.464888895346 Hz
# Obdelava frekvence 107 od 257: 6255.105583925964 Hz
# Obdelava frekvence 108 od 257: 6255.586105198929 Hz
# Obdelava frekvence 109 od 257: 6256.70732150251 Hz
# Obdelava frekvence 110 od 257: 6257.828537806092 Hz
# Obdelava frekvence 111 od 257: 6258.629406594365 Hz
# Obdelava frekvence 112 od 257: 6259.270101624983 Hz
# Obdelava frekvence 113 od 257: 6259.910796655601 Hz
# Obdelava frekvence 114 od 257: 6260.551491686219 Hz
# Obdelava frekvence 115 od 257: 6261.352360474492 Hz
# Obdelava frekvence 116 od 257: 6261.832881747456 Hz
# Obdelava frekvence 117 od 257: 6262.473576778074 Hz
# Obdelava frekvence 118 od 257: 6262.7939242933835 Hz
# Obdelava frekvence 119 od 257: 6263.274445566347 Hz
# Obdelava frekvence 120 od 257: 6263.5947930816565 Hz
# Obdelava frekvence 121 od 257: 6264.235488112275 Hz
# Obdelava frekvence 122 od 257: 6264.716009385238 Hz
# Obdelava frekvence 123 od 257: 6265.356704415856 Hz
# Obdelava frekvence 124 od 257: 6265.837225688821 Hz
# Obdelava frekvence 125 od 257: 6266.638094477093 Hz
# Obdelava frekvence 126 od 257: 6267.438963265366 Hz
# Obdelava frekvence 127 od 257: 6268.400005811293 Hz
# Obdelava frekvence 128 od 257: 6269.521222114875 Hz
# Obdelava frekvence 129 od 257: 6270.322090903148 Hz
# Obdelava frekvence 130 od 257: 6271.122959691421 Hz
# Obdelava frekvence 131 od 257: 6272.404349752657 Hz
# Obdelava frekvence 132 od 257: 6273.525566056239 Hz
# Obdelava frekvence 133 od 257: 6274.326434844512 Hz
# Obdelava frekvence 134 od 257: 6274.806956117475 Hz
# Obdelava frekvence 135 od 257: 6275.447651148094 Hz
# Obdelava frekvence 136 od 257: 6276.408693694021 Hz
# Obdelava frekvence 137 od 257: 6276.889214966985 Hz
# Obdelava frekvence 138 od 257: 6277.690083755258 Hz
# Obdelava frekvence 139 od 257: 6278.4909525435305 Hz
# Obdelava frekvence 140 od 257: 6279.612168847112 Hz
# Obdelava frekvence 141 od 257: 6280.733385150695 Hz
# Obdelava frekvence 142 od 257: 6281.6944276966215 Hz
# Obdelava frekvence 143 od 257: 6282.33512272724 Hz
# Obdelava frekvence 144 od 257: 6282.975817757859 Hz
# Obdelava frekvence 145 od 257: 6283.616512788477 Hz
# Obdelava frekvence 146 od 257: 6285.218250365022 Hz
# Obdelava frekvence 147 od 257: 6286.17929291095 Hz
# Obdelava frekvence 148 od 257: 6286.819987941568 Hz
# Obdelava frekvence 149 od 257: 6287.9412042451495 Hz
# Obdelava frekvence 150 od 257: 6288.421725518114 Hz
# Obdelava frekvence 151 od 257: 6290.664158125277 Hz
# Obdelava frekvence 152 od 257: 6292.105721944168 Hz
# Obdelava frekvence 153 od 257: 6293.066764490096 Hz
# Obdelava frekvence 154 od 257: 6293.707459520714 Hz
# Obdelava frekvence 155 od 257: 6294.348154551332 Hz
# Obdelava frekvence 156 od 257: 6294.9888495819505 Hz
# Obdelava frekvence 157 od 257: 6297.231282189115 Hz
# Obdelava frekvence 158 od 257: 6297.871977219733 Hz
# Obdelava frekvence 159 od 257: 6301.2356261304785 Hz
# Obdelava frekvence 160 od 257: 6302.517016191715 Hz
# Obdelava frekvence 161 od 257: 6305.239970071842 Hz
# Obdelava frekvence 162 od 257: 6305.720491344806 Hz
# Obdelava frekvence 163 od 257: 6306.20101261777 Hz
# Obdelava frekvence 164 od 257: 6306.841707648388 Hz
# Obdelava frekvence 165 od 257: 6307.322228921352 Hz
# Obdelava frekvence 166 od 257: 6308.923966497898 Hz
# Obdelava frekvence 167 od 257: 6309.564661528516 Hz
# Obdelava frekvence 168 od 257: 6313.729179227535 Hz
# Obdelava frekvence 169 od 257: 6314.530048015807 Hz
# Obdelava frekvence 170 od 257: 6316.772480622971 Hz
# Obdelava frekvence 171 od 257: 6321.898040867917 Hz
# Obdelava frekvence 172 od 257: 6325.742211051626 Hz
# Obdelava frekvence 173 od 257: 6327.023601112863 Hz
# Obdelava frekvence 174 od 257: 7840.665610948476 Hz
# Obdelava frekvence 175 od 257: 7852.998990287877 Hz
# Obdelava frekvence 176 od 257: 7859.085593078751 Hz
# Obdelava frekvence 177 od 257: 7862.289068231842 Hz
# Obdelava frekvence 178 od 257: 7864.211153323697 Hz
# Obdelava frekvence 179 od 257: 7865.492543384933 Hz
# Obdelava frekvence 180 od 257: 7866.133238415551 Hz
# Obdelava frekvence 181 od 257: 7866.934107203824 Hz
# Obdelava frekvence 182 od 257: 7867.734975992097 Hz
# Obdelava frekvence 183 od 257: 7868.375671022715 Hz
# Obdelava frekvence 184 od 257: 7868.856192295679 Hz
# Obdelava frekvence 185 od 257: 7869.336713568643 Hz
# Obdelava frekvence 186 od 257: 7869.977408599261 Hz
# Obdelava frekvence 187 od 257: 7870.618103629879 Hz
# Obdelava frekvence 188 od 257: 7871.418972418152 Hz
# Obdelava frekvence 189 od 257: 7872.2198412064245 Hz
# Obdelava frekvence 190 od 257: 7873.341057510007 Hz
# Obdelava frekvence 191 od 257: 7874.622447571243 Hz
# Obdelava frekvence 192 od 257: 7875.102968844207 Hz
# Obdelava frekvence 193 od 257: 7875.583490117171 Hz
# Obdelava frekvence 194 od 257: 7876.224185147789 Hz
# Obdelava frekvence 195 od 257: 7876.704706420753 Hz
# Obdelava frekvence 196 od 257: 7877.185227693716 Hz
# Obdelava frekvence 197 od 257: 7877.6657489666795 Hz
# Obdelava frekvence 198 od 257: 7878.146270239644 Hz
# Obdelava frekvence 199 od 257: 7878.786965270262 Hz
# Obdelava frekvence 200 od 257: 7879.42766030088 Hz
# Obdelava frekvence 201 od 257: 7880.388702846808 Hz
# Obdelava frekvence 202 od 257: 7880.869224119771 Hz
# Obdelava frekvence 203 od 257: 7881.50991915039 Hz
# Obdelava frekvence 204 od 257: 7882.470961696316 Hz
# Obdelava frekvence 205 od 257: 7883.1116567269355 Hz
# Obdelava frekvence 206 od 257: 7883.752351757554 Hz
# Obdelava frekvence 207 od 257: 7884.232873030517 Hz
# Obdelava frekvence 208 od 257: 7885.03374181879 Hz
# Obdelava frekvence 209 od 257: 7885.674436849408 Hz
# Obdelava frekvence 210 od 257: 7885.994784364717 Hz
# Obdelava frekvence 211 od 257: 7886.635479395335 Hz
# Obdelava frekvence 212 od 257: 7887.116000668299 Hz
# Obdelava frekvence 213 od 257: 7887.756695698918 Hz
# Obdelava frekvence 214 od 257: 7888.397390729536 Hz
# Obdelava frekvence 215 od 257: 7888.877912002499 Hz
# Obdelava frekvence 216 od 257: 7890.159302063736 Hz
# Obdelava frekvence 217 od 257: 7891.921213397936 Hz
# Obdelava frekvence 218 od 257: 7894.1636460050995 Hz
# Obdelava frekvence 219 od 257: 7894.804341035718 Hz
# Obdelava frekvence 220 od 257: 7895.9255573393 Hz
# Obdelava frekvence 221 od 257: 7898.00781618881 Hz
# Obdelava frekvence 222 od 257: 7898.488337461773 Hz
# Obdelava frekvence 223 od 257: 7902.332507645482 Hz
# Obdelava frekvence 224 od 257: 7902.973202676101 Hz
# Obdelava frekvence 225 od 257: 7904.254592737338 Hz
# Obdelava frekvence 226 od 257: 7908.739457951665 Hz
# Obdelava frekvence 227 od 257: 7913.384496923647 Hz
# Obdelava frekvence 228 od 257: 7919.951620987485 Hz
# Obdelava frekvence 229 od 257: 7921.55335856403 Hz
# Obdelava frekvence 230 od 257: 7922.194053594649 Hz
# Obdelava frekvence 231 od 257: 7940.774209482577 Hz
# Obdelava frekvence 232 od 257: 7956.791585248034 Hz
# Obdelava frekvence 233 od 257: 9583.035746714804 Hz
# Obdelava frekvence 234 od 257: 9584.156963018386 Hz
# Obdelava frekvence 235 od 257: 9587.360438171478 Hz
# Obdelava frekvence 236 od 257: 9589.122349505678 Hz
# Obdelava frekvence 237 od 257: 9590.403739566915 Hz
# Obdelava frekvence 238 od 257: 9591.845303385806 Hz
# Obdelava frekvence 239 od 257: 9596.009821084823 Hz
# Obdelava frekvence 240 od 257: 9597.131037388406 Hz
# Obdelava frekvence 241 od 257: 9598.732774964952 Hz
# Obdelava frekvence 242 od 257: 9599.213296237915 Hz
# Obdelava frekvence 243 od 257: 9600.81503381446 Hz
# Obdelava frekvence 244 od 257: 9601.615902602733 Hz
# Obdelava frekvence 245 od 257: 9603.377813936933 Hz
# Obdelava frekvence 246 od 257: 9606.74146284768 Hz
# Obdelava frekvence 247 od 257: 9613.148413153862 Hz
# Obdelava frekvence 248 od 257: 9615.390845761025 Hz
# Obdelava frekvence 249 od 257: 9616.191714549299 Hz
# Obdelava frekvence 250 od 257: 9616.992583337571 Hz
# Obdelava frekvence 251 od 257: 9620.996927278935 Hz
# Obdelava frekvence 252 od 257: 9622.438491097826 Hz
# Obdelava frekvence 253 od 257: 9625.481792493263 Hz
# Obdelava frekvence 254 od 257: 9626.122487523882 Hz
# Obdelava frekvence 255 od 257: 9626.7631825545 Hz
# Obdelava frekvence 256 od 257: 13488.392305848341 Hz
# Obdelava frekvence 257 od 257: 13490.47456469785 Hz
